# %%
import json
import urllib.request
import time
from IPython.display import display, Markdown

OLLAMA_URL   = "http://localhost:11434/api/generate"
OLLAMA_MODEL = "mistral"

ZONES_TEST = {
    "Méditerranée": "Mer Méditerranée, mer Égée, mer Adriatique, détroit de Gibraltar, archipel grec",
    "Océan Pacifique Sud": "Océan Pacifique Sud, Polynésie, Mélanésie, côtes australiennes"
}

def appeler_ollama(prompt, num_predict=2000):
    payload = json.dumps({
        "model": OLLAMA_MODEL,
        "prompt": prompt,
        "stream": False,
        "options": {"temperature": 0.2, "num_predict": num_predict}
    }).encode("utf-8")
    req = urllib.request.Request(
        OLLAMA_URL, data=payload,
        headers={"Content-Type": "application/json"}, method="POST"
    )
    try:
        with urllib.request.urlopen(req, timeout=180) as resp:
            return json.loads(resp.read().decode("utf-8")).get("response", "").strip()
    except Exception as e:
        return f"Erreur Ollama : {e}"

def prompt_comparaison(nom_zone, description_zone):
    return f"""Tu es un scientifique marin et historien spécialisé dans l'environnement océanique.

ZONE GÉOGRAPHIQUE : {nom_zone}
DESCRIPTION : {description_zone}

TÂCHE : Rédige une comparaison entre la connaissance maritime de cette zone en 1866 et aujourd'hui.

STRUCTURE OBLIGATOIRE en 4 sections :

⚓ AU XIXe SIÈCLE (vers 1866)
Décris les techniques de navigation, les outils disponibles, les connaissances scientifiques et l'état de la faune marine à cette époque dans cette zone.

🌊 AUJOURD'HUI
Décris l'état actuel de l'écosystème marin, les nouvelles espèces découvertes, les technologies modernes d'exploration.

⚠️ PROBLÈMES ENVIRONNEMENTAUX ACTUELS
Cite les problèmes spécifiques à cette zone : surpêche, réchauffement climatique, acidification, pollution plastique, espèces menacées.

📜 LOIS ET PROTECTIONS EN VIGUEUR
Cite les lois de pêche, accords internationaux et zones marines protégées actuellement en vigueur dans cette zone.

RÈGLES :
- Faits réels et vérifiables uniquement
- Texte littéraire, fluide, pas de tableaux ni de listes à puces
- Chaque section fait 3 à 5 phrases
- Réponse en français uniquement
- Pas de mention de Jules Verne
"""

resultats = {}

for nom_zone, description in ZONES_TEST.items():
    print(f"\n{'='*55}")
    print(f"⚖️  {nom_zone}")
    print(f"{'='*55}")
    print("🤖 Ollama en cours...")

    reponse = appeler_ollama(prompt_comparaison(nom_zone, description))
    resultats[nom_zone] = reponse

    display(Markdown(f"""
---
### ⚖️ {nom_zone}
{reponse}
---
"""))
    time.sleep(2)

print("\n✅ Test terminé !")
# Out:
# =======================================================
# ⚖️  Méditerranée
# =======================================================
# 🤖 Ollama en cours...
# ---
# ### ⚖️ Méditerranée
# ⚓ AU XIXe SIÈCLE (vers 1866)
# Les techniques de navigation dans la Méditerranée étaient basées sur les cartes nautiques et les instruments tels que le compas, le chronomètre et la brasse. Les connaissances scientifiques étaient limitées, avec une compréhension incomplète des courants marins et de la faune marine. La faune marine était abondante, mais l'exploitation intensive n'était pas encore un problème majeur.
#
# 🌊 AUJOURD'HUI
# Aujourd'hui, les technologies d'exploration marines ont évolué considérablement avec l'utilisation de sonars et de satellites pour cartographier la Méditerranée. Les connaissances scientifiques ont également progressé grâce à des recherches sur les courants marins, la biodiversité marine et le changement climatique. De nouvelles espèces ont été découvertes, mais l'état de l'écosystème marin est préoccupant en raison de la surpêche, du réchauffement climatique, de l'acidification des eaux et de la pollution plastique.
#
# ⚠️ PROBLÈMES ENVIRONNEMENTAUX ACTUELS
# Les problèmes environnementaux spécifiques à cette zone comprennent la surpêche, qui menace plusieurs espèces marines, le réchauffement climatique, qui affecte les courants marins et la biodiversité marine, l'acidification des eaux, qui peut entraîner la mortalité de coraux et d'autres organismes calcaires, la pollution plastique, qui menace les espèces marines et les écosystèmes côtiers, ainsi que la perte d'espèces menacées.
#
# 📜 LOIS ET PROTECTIONS EN VIGUEUR
# Il existe des lois de pêche nationales dans chaque pays riverain de la Méditerranée, ainsi qu'un accord international, le Plan d'Action pour la Méditerranée (PAM), qui vise à protéger l'environnement marin. De plus, il y a des zones marines protégées telles que les parcs nationaux marins et les réserves naturelles marines.
# ---
# =======================================================
# ⚖️  Océan Pacifique Sud
# =======================================================
# 🤖 Ollama en cours...
# ---
# ### ⚖️ Océan Pacifique Sud
# ⚓ AU XIXe SIÈCLE (vers 1866)
# Les techniques de navigation dans l'Océan Pacifique Sud étaient basées sur la connaissance ancestrale des Polynésiens et Melanésiens, qui utilisaient les étoiles, le soleil, la lune et les courants marins pour se déplacer. Les outils disponibles comprenaient des canoës à voile et des pirogues. La connaissance scientifique était limitée, et la faune marine était mal explorée, bien que certains poissons, comme le thon bleu et le marlin, soient déjà connus pour leur importance économique.
#
# 🌊 AUJOURD'HUI
# Aujourd'hui, l'exploration de l'écosystème marin dans cette zone est plus avancée grâce aux technologies modernes telles que les sonars et les satellites. De nouvelles espèces ont été découvertes, comme le requin-lézard des Galápagos qui a été observé dans les eaux australiennes. Les populations de certaines espèces marines sont en déclin, mais d'autres ont prospéré grâce à la protection des zones marines.
#
# ⚠️ PROBLÈMES ENVIRONNEMENTAUX ACTUELS
# Les principaux problèmes environnementaux actuels dans cette zone sont la surpêche, qui menace les populations de certaines espèces marines comme le thon bleu et le dauphin commun, le réchauffement climatique, qui affecte les coraux de la Grande Barrière australienne, l'acidification des océans, qui menace les espèces calcaires, la pollution plastique, qui endommage les habitats marins et les organismes marins, et la perte d'espèces menacées comme le manchot royal.
#
# 📜 LOIS ET PROTECTIONS EN VIGUEUR
# Il existe des lois de pêche nationales dans chaque pays de cette zone, ainsi qu'un certain nombre d'accords internationaux pour protéger les ressources marines et les espèces menacées. Par exemple, la Convention sur la conservation des espèces migratrices de faune sauvage en Afrique et en Asie (CMS) protège le dauphin commun dans toute l'océan Pacifique. De plus, il existe plusieurs zones marines protégées, comme la Réserve marine du Grand Nord, qui couvre une grande partie des eaux australiennes.
# ---
# ✅ Test terminé !
